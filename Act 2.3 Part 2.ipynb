# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
x = [10, 20, 30, 40]

# %%
y = [0, 15, 10, 25]

# %%
plt.plot(x, y)

# %%
sns.set()

# %%
plt.plot(x, y)

# %%
sns.set_style("white")

# %%
plt.plot(x, y)

# %% [raw]
# cars = sns.load_dataset('mpg')

# %%
type(cars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 type(cars)
#
# NameError: name 'cars' is not defined

# %%
cars.dropna(inplace=True)

cars.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cars.dropna(inplace=True)
#       3 cars.shape
#
# NameError: name 'cars' is not defined

# %%
cars.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cars.head()
#
# NameError: name 'cars' is not defined

# %%
sns.relplot(x='model_year', y='mpg', col='origin', hue='cylinders', data=cars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.relplot(x='model_year', y='mpg', col='origin', hue='cylinders', data=cars)
#
# NameError: name 'cars' is not defined
